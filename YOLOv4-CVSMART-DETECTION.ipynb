# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# import os
# %matplotlib inline
# import matplotlib.image as mpimg
# import matplotlib.pyplot as plt

# %%
# !ln -s "/content/drive/My Drive/" /mydrive

# %%
# path = '/mydrive/ML/ObjectDetection/darknet/data/CVSmart/'
# os.chdir(path)

# %%
# !git clone https://github.com/AlexeyAB/darknet

# %%
# !/usr/local/cuda/bin/nvcc --version

# %%
# %cd ../../../darknet/
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# !sed -i 's/LIBSO=0/LIBSO=1/' Makefile

# %%
# !make

# %%
# !./darknet

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %%
# path = '/mydrive/ML/ObjectDetection/darknet/data/CVSmart/obj_data'
# os.chdir(path)

# %%
# path_list = []
# for current_dir, dirs, files in os.walk('.'):
#   for f in files:
#     if f.endswith('.PNG'):
#       path_list.append(path + '/' + f)

# len(path_list)

# %%
# split = int(len(path_list)*0.9)
# split

# %%
# for i, f in enumerate(path_list[:split]):
#   print(i, f)

# %%
# for i, f in enumerate(path_list[split:]):
#   print(i, f)

# %%
# !chmod +x ./darknet

# %%
# with open('/mydrive/ML/ObjectDetection/darknet/data/CVSmart/train.txt', 'w') as train:
#   for f in path_list[:split]:
#     train.write(f + "\n")

# %%
# with open('/mydrive/ML/ObjectDetection/darknet/data/CVSmart/valid.txt', 'w') as valid:
#   for f in path_list[split:]:
#     valid.write(f + "\n")

# %%
# import torch

# %%
# import imageio
# img_arr = imageio.imread(path_list[100])
# img_arr.shape

# %%
# img = mpimg.imread(path_list[100])
# plt.figure(figsize = (12,12))
# plt.imshow(img)
# print(path_list[100])

# %%
# path = '/mydrive/ML/ObjectDetection/darknet'
# os.chdir(path)

# %%
# !sudo chmod +x darknet

# %%
# !./darknet detector train "data/CVSmart/obj.data" "data/CVSmart/custom-train.cfg" "data/CVSmart/yolov4.conv.137" -dont_show -map -clear

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# !ln -s "/content/drive/My Drive/" /mydrive

path = '/mydrive/ML/ObjectDetection/darknet'
os.chdir(path)

# !sudo chmod +x darknet
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/My Drive': File exists

# %%
# !./darknet detector train "data/CVSmart/obj.data" "data/CVSmart/custom-train.cfg" "data/CVSmart/weights/custom-train_last.weights" -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 1716432, rewritten_bbox = 0.218535 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.920170), count: 131, class_loss = 7.218296, iou_loss = 1750.164307, total_loss = 1757.382568
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.954699), count: 143, class_loss = 1.632421, iou_loss = 660.550232, total_loss = 662.182678
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.956499), count: 37, class_loss = 0.417682, iou_loss = 34.873024, total_loss = 35.290707
#  total_bbox = 1716743, rewritten_bbox = 0.218495 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.915341), count: 104, class_loss = 3.117002, iou_loss = 1414.958496, total_loss = 1418.075439
# ...
