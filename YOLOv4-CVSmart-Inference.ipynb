# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# !ln -s "/content/drive/My Drive/" /mydrive
path = '/mydrive/ML/ObjectDetection/darknet'
os.chdir(path)

# %%
# !./darknet detector train "data/barcodes_dataset/image_data.data" "cfg/yolov4-train.cfg" "yolov4.conv.137" -dont_show -map
# !sudo chmod +x darknet

# %%
# !./darknet detector demo "data/CVSmart/obj.data" "data/CVSmart/custom-test.cfg" "data/CVSmart/weights/custom-train_best.weights" -dont_show "data/CVSmart/test_site_video10_in.mp4" -thresh 0.3 -i 0 -out_filename "data/CVSmart/test_site_video10_out.mp4"
# Out:
# Streaming output truncated to the last 5000 lines.
# Roadblock: 100%
# Roadblock: 100%
# Roadblock: 100%
# Roadblock: 100%
#
# FPS:11.0 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# Car: 100%
# Portable Lighting: 100%
# Portable Lighting: 100%
# Articulated Hauler: 100%
# Articulated Hauler: 100%
# Roller: 100%
# Roller: 100%
# Caterpillar D11T: 100%
# Traffic Cone: 100%
# Traffic Cone: 100%
# Traffic Cone: 100%
# Traffic Cone: 100%
# Traffic Cone: 100%
# Volvo Excavator: 100%
# Volvo Excavator: 99%
# Roadblock: 100%
# Roadblock: 100%
# Roadblock: 100%
# Roadblock: 100%
# Roadblock: 100%
# Roadblock: 100%
# Roadblock: 100%
# Roadblock: 100%
#
# FPS:10.8 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# Car: 100%
# Portable Lighting: 100%
# Portable Lighting: 100%
# Articulated Hauler: 100%
# Articulated Hauler: 100%
# Roller: 100%
# Roller: 100%
# Caterpillar D11T: 100%
# Traffic Cone: 100%
# Traffic Cone: 100%
# Traffic Cone: 100%
# Traffic Cone: 100%
# Traffic Cone: 100%
# ...
